# %%
#sentiment analysis is the analysis of the data of which is in the form of sentences generated by  humans to check
#for the positivity and negativity of the sentence. also how much the sentence weights..

# %%
#first of all generate an application from twitter api.(twitter apssp)
#which will provide the nesessary infomation for accessing the server's data

# %%
#download dependencies..
#textblob,tweepy

# %%
#importing dependencies
from textblob import TextBlob
import nltk
import tweepy

# %%
#the below details can be fetehed by the twitter apps.. and its ment to be kept personal

# %%
consumer_key='#value from the twitter api'
consumer_secret='#value from the twitter api'
access_token='#value from the twitter api'
access_token_secret='#value from the twitter api'

# %%
#authenticating our app details with that of the server..!

auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

# %%
#creating an api object that will be useful to get the data from the twitter application created.
api=tweepy.API(auth)

# %%
#creating a variable that stores the json file comming from the server with the search of a particular keyword.
public_tweets1=api.search('Trump')
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-17-7d598de20dfc> in <module>()
#       1 #creating a variable that stores the json file comming from the server with the search of a particular keyword.
# ----> 2 public_tweets1=api.search('Modi')
#
# ~/miniconda3/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# ~/miniconda3/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     227                     raise RateLimitError(error_msg, resp)
#     228                 else:
# --> 229                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     230
#     231             # Parse the response payload
#
# ...

# %%
#iterate through the data obtained from twitter 

for tweets in public_tweets:
    print (tweets.text)
    analysis=TextBlob(tweets.text)
    print(analysis.sentiment)

# %%
#here the polarity means the negativity and positivity of the setenece
#polarity < 0 means the sentence is negative
#polarity > 0 means the sentence is positive

# %%
 #the subjectivity means what value (weight) does the sentence carries.
